# %% [markdown]
# <a href="https://colab.research.google.com/github/am11449/data-puzzles.com/blob/main/Data_puzzles_Visu_C1_Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problem summary
#
# Can you find the silhouette hidden in this dataset?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/hyperc54/data-puzzles-assets/master/visualisation/chal1/chal_visu_1_q2_data.csv')
df.head()
# Out:
#     feature_0   feature_1   feature_2   feature_3   feature_4   feature_5  \
# 0  311.501194 -434.375063  465.724596  -13.756244   63.154977 -293.572478
# 1  278.741781 -553.400130  276.383054   48.562182   42.452864 -368.840239
# 2  416.016118 -643.424492  367.760502  131.633500   23.159960 -366.994592
# 3  267.473168 -759.908836  336.770534   79.037171  104.378434 -175.572765
# 4  333.826916 -740.880883  245.520497  -31.536664   27.130920 -573.016784
#
#    feature_6
# 0 -74.132678
# 1 -74.595382
# 2 -77.408354
# 3 -74.561150
# 4 -73.475911

# %% [markdown]
# # Your turn!

# %%
# According to hint I need to use a scatterplot matrix, there's really nothing else given here
from pandas.plotting import scatter_matrix

scatter_matrix(df, figsize = (6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5e3d1a9d90>,
# ...
#       dtype=object)

# %%
#Something interesting betwwen feature 2 and feature 5, lets plot it seperately

plt.scatter(df.feature_2, df.feature_5)

# %%
#Looks like unicorn
